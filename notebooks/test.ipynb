# %%
import sys
import os

# Adds the project root to the Python path
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from IPython.display import Image, display
from langgraph.checkpoint.memory import MemorySaver
from app.core.pipeline import MedicalInsightsPipeline, get_gemma_model, visualize_graph

# %%
from langchain_openrouter import ChatOpenRouter


model = get_gemma_model()

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = model.invoke(messages)
ai_msg.content
# Out:
# "J'adore la programmation."

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to Spanish. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = model.invoke(messages)
ai_msg.content
# Out:
# 'Me encanta programar.'

# %%
display(Image(visualize_graph()))
