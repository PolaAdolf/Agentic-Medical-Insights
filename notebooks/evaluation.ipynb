# %%
import sys


appand_path = 'Agentic-Medical-Insights'
if appand_path not in sys.path:
   sys.path.append(appand_path)
from app.core.pipeline import MedicalInsightsPipeline
import asyncio

SAMPLE_REPORT = 'sample.pdf'

with open(SAMPLE_REPORT, 'rb') as f:
    file_bytes = f.read()

pipeline = MedicalInsightsPipeline()

initial_state = {'file_bytes': file_bytes, 'filename': 'sample.pdf'}
state = await pipeline.ocr_node(initial_state)

print('Pipeline completed!')
print('Stage:', state.get('current_stage' ))
print('Report type:', state.get('report_type'))
print('OCR Markdown:')
print(state.get('ocr_markdown'))
print('callable:', callable(state.get('ocr_markdown')))
print(state.get('ocr_markdown'))
# Out:
# Pipeline completed!
# Stage: ocr_complete
# Report type: CBC
# OCR Markdown:
# # CBC: Complete Blood Count (CBC)
#
# ## Patient Information
# | Name | Age | Gender | Date | Physician |
# | :--- | :--- | :--- | :--- | :--- |
# | John Doe | 35 | Not provided | Not provided | Not provided |
#
# ## Lab Results
# | Analyte | Value | Unit | Reference Range | Flag |
# | :--- | :--- | :--- | :--- | :--- |
# | Hemoglobin | 13.5 | g/dL | Not provided | NORMAL |
# | WBC | 7.2 | x10^3/uL | Not provided | NORMAL |
# | RBC | 4.8 | x10^6/uL | Not provided | NORMAL |
# | Platelets | 250 | x10^3/uL | Not provided | NORMAL |
# callable: False
# # CBC: Complete Blood Count (CBC)
#
# ## Patient Information
# | Name | Age | Gender | Date | Physician |
# | :--- | :--- | :--- | :--- | :--- |
# | John Doe | 35 | Not provided | Not provided | Not provided |
#
# ## Lab Results
# | Analyte | Value | Unit | Reference Range | Flag |
# | :--- | :--- | :--- | :--- | :--- |
# ...

# %%
import sys


appand_path = 'Agentic-Medical-Insights'
if appand_path not in sys.path:
   sys.path.append(appand_path)
from app.core.pipeline import MedicalInsightsPipeline
import asyncio

SAMPLE_REPORT = 'sample.png'

with open(SAMPLE_REPORT, 'rb') as f:
    file_bytes = f.read()

pipeline = MedicalInsightsPipeline()

initial_state = {'file_bytes': file_bytes, 'filename': 'sample.png'}
state = await pipeline.ocr_node(initial_state)

print('Pipeline completed!')
print('Stage:', state.get('current_stage' ))
print('Report type:', state.get('report_type'))
print('OCR Markdown:')
print(state.get('ocr_markdown'))
print('callable:', callable(state.get('ocr_markdown')))
print(state.get('ocr_markdown'))
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# C:\Users\aaahm\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Pipeline completed!
# Stage: ocr_complete
# Report type: CBC
# OCR Markdown:
# # CBC – MEDILAB Laboratory Services
#
# ## Patient Information
# | Name | Age | Gender | Date | Physician |
# |------|-----|--------|------|-----------|
# | Sarah Ahmed | 28 Years | Female | 18-May-2024 | Dr. Nadia Khan |
#
# ## Lab Results
# | Analyte | Value | Unit | Reference Range | Flag |
# |---------|-------|------|-----------------|------|
# | Hemoglobin (Hb) | 12.6 | g/dL | 12.0‑16.0 | NORMAL |
# | Hematocrit (Hct) | 37.8 | % | 36‑46 | NORMAL |
# | RBC Count | 4.25 | x10^6/uL | 3.80‑5.20 | NORMAL |
# | MCV | 88.9 | fL | 80‑96 | NORMAL |
# ...

# %%
# =========================
# wxtract output formatting
# =========================

import sys


appand_path = 'c:/OneDrive/Documents/GitHub/Agentic-Medical-Insights'
if appand_path not in sys.path:
   sys.path.append(appand_path)
from app.core.pipeline import MedicalInsightsPipeline
import asyncio

SAMPLE_REPORT = 'c:/OneDrive/Documents/GitHub/Agentic-Medical-Insights/sample.pdf'

with open(SAMPLE_REPORT, 'rb') as f:
    file_bytes = f.read()

pipeline = MedicalInsightsPipeline()
# markdown from OCR node
initial_state = {'file_bytes': file_bytes, 'filename': 'sample.pdf'}
state1 = await pipeline.ocr_node(initial_state)

state = await pipeline.extraction_node(state1)
print('Pipeline completed!')
print('Stage:', state.get('current_stage' ))  
print('Patient Info:', state.get('patient_info'))
print('Lab Values:', state.get('lab_values')) 
print('Clinical Notes:', state.get('clinical_notes'))
print('Context Markdown:')
print(state.get('context_markdown'))
print('########################################################################################')
print('Module 2 Output:')
print(state.get('module_2_output'))
# Out:
# Pipeline completed!
# Stage: extraction_complete
# Patient Info: {'patient_name': 'John Doe', 'age': '35', 'gender': 'Not found', 'report_date': 'Not found', 'lab_name': 'Not found', 'physician': 'Not found'}
# Lab Values: [{'test_name': 'CBC - Hemoglobin', 'value': '13.5', 'unit': 'g/dL', 'reference_range': 'Not found', 'flag': 'NORMAL', 'category': 'CBC'}, {'test_name': 'CBC - WBC', 'value': '7.2', 'unit': 'x10^3/uL', 'reference_range': 'Not found', 'flag': 'NORMAL', 'category': 'CBC'}, {'test_name': 'CBC - RBC', 'value': '4.8', 'unit': 'x10^6/uL', 'reference_range': 'Not found', 'flag': 'NORMAL', 'category': 'CBC'}, {'test_name': 'CBC - Platelets', 'value': '250', 'unit': 'x10^3/uL', 'reference_range': 'Not found', 'flag': 'NORMAL', 'category': 'CBC'}]
# Clinical Notes: {'notes': []}
# Context Markdown:
# # Extracted Context: CBC
#
# ## Patient Information
#
# | Field | Value |
# |-------|-------|
# | Patient Name | John Doe |
# | Age | 35 |
# | Gender | Not found |
# ...

# %%
# =========================

# =========================

import sys


appand_path = 'c:/OneDrive/Documents/GitHub/Agentic-Medical-Insights'
if appand_path not in sys.path:
   sys.path.append(appand_path)
from app.core.pipeline import MedicalInsightsPipeline

import asyncio

SAMPLE_REPORT = 'c:/OneDrive/Documents/GitHub/Agentic-Medical-Insights/sample2.png'

with open(SAMPLE_REPORT, 'rb') as f:
    file_bytes = f.read()

pipeline = MedicalInsightsPipeline()
# markdown from OCR node
initial_state = {'file_bytes': file_bytes, 'filename': 'sample2.png'}
state = await pipeline.ocr_node(initial_state)
state1 = await pipeline.extraction_node(state)
state2 = await pipeline.search_node(state1)
print('Pipeline completed!')
print('Stage:', state2.get('current_stage' ))
print('Patient Info:', state2.get('patient_info'))
print('search_queries:', state2.get('search_queries'))
print('pubmed_abstracts:', state2.get('pubmed_abstracts'))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# C:\Users\aaahm\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# 2026/05/12 12:17:42 WARNING dspy.primitives.module: Calling module.forward(...) on SearchModule directly is discouraged. Please use module(...) instead.
# [Module3] lab_values count:  15
# [Module3] abnormal count:    14
# [Module3] report_type:       CBC
# [Module3] patient_info:      {'patient_name': 'Sarah Ahmed', 'age': '28 Years', 'gender': 'Female', 'report_date': '18-May-2024', 'lab_name': 'City Diagnostic Lab', 'physician': 'Dr Nadia Khan'}
# [Module3] Context sent to LLM:
# {
#   "report_type": "CBC",
#   "patient": {
#     "age": "28 Years",
#     "gender": "Female"
#   },
#   "abnormal_values": [
#     {
#       "name": "CBC - Hemoglobin (Hb)",
#       "value": "9.8",
# ...

# %%
# =========================

# =========================

import sys


appand_path = 'c:/OneDrive/Documents/GitHub/Agentic-Medical-Insights'
if appand_path not in sys.path:
   sys.path.append(appand_path)
from app.core.pipeline import MedicalInsightsPipeline

import asyncio

SAMPLE_REPORT = 'c:/OneDrive/Documents/GitHub/Agentic-Medical-Insights/sample2.png'

with open(SAMPLE_REPORT, 'rb') as f:
    file_bytes = f.read()

pipeline = MedicalInsightsPipeline()
# markdown from OCR node
initial_state = {'file_bytes': file_bytes, 'filename': 'sample2.png'}
state = await pipeline.ocr_node(initial_state)
state1 = await pipeline.extraction_node(state)
state2 = await pipeline.search_node(state1)
state3 = await pipeline.analysis_node(state2)
print('Pipeline completed!')
print('final report markdown:')
print(state3.get('final_report_markdown'))
state4 = await pipeline.evaluation_node(state3)

print('Pipeline completed!')
print('Stage:', state4.get('current_stage' ))

print('quality_scores:', state4.get('quality_scores'))
print('evaluation_passed:', state4.get('evaluation_passed'))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# C:\Users\aaahm\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# 2026/05/13 18:19:27 WARNING dspy.primitives.module: Calling module.forward(...) on SearchModule directly is discouraged. Please use module(...) instead.
# [Module3] lab_values: 15, abnormal: 14
# [Module3] report_type: CBC
# [Module3] Fallback queries: ['iron deficiency anemia reactive thrombocytosis', 'low hemoglobin high platelets iron deficiency women', 'microcytic hypochromic anemia iron deficiency diagnosis', 'extreme thrombocytosis differential diagnosis myeloproliferative', 'essential thrombocythemia young adults diagnosis', 'leukocytosis differential diagnosis infection myeloproliferative']
# [Module3] LLM generated 7 queries
# ...

# %%
# =========================

# =========================

import sys


appand_path = 'c:/OneDrive/Documents/GitHub/Agentic-Medical-Insights'
if appand_path not in sys.path:
   sys.path.append(appand_path)
from app.core.pipeline import MedicalInsightsPipeline

import asyncio

SAMPLE_REPORT = 'c:/OneDrive/Documents/GitHub/Agentic-Medical-Insights/sample2.png'

with open(SAMPLE_REPORT, 'rb') as f:
    file_bytes = f.read()

pipeline = MedicalInsightsPipeline()
# markdown from OCR node
initial_state = {'file_bytes': file_bytes, 'filename': 'sample2.png'}
state = await pipeline.ocr_node(initial_state)
state1 = await pipeline.extraction_node(state)
state2 = await pipeline.search_node(state1)
state3 = await pipeline.analysis_node(state2)
print('Pipeline completed!')
print('final report markdown:')
print(state3.get('final_report_markdown'))
state4 = await pipeline.evaluation_node(state3)

print('Pipeline completed!')
print('Stage:', state4.get('current_stage' ))

print('quality_scores:', state4.get('quality_scores'))
print('evaluation_passed:', state4.get('evaluation_passed'))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Performing OCR on the document...
# C:\Users\aaahm\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OCR complete.
# Extracting structured context from OCR output...
# Context extraction complete.
# Pipeline completed!
# final report markdown:
# ---
# **Agentic Medical Insights** | Patient: Sarah Ahmed | Generated: 2026-05-14 22:52 UTC
#
# ---
#
# # Clinical Report – Complete Blood Count (CBC)
#
# **Patient:** Sarah Ahmed (28‑year‑old female)
# **Date of Report:** 18‑May‑2024
# **Lab:** City Diagnostic Lab
# **Referring Physician:** Dr. Nadia Khan
#
# ---
#
# ## 1. Executive Summary
# ...
